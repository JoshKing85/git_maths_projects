# %% [markdown]
# ### Complex Numbers

# %%
import math
import numpy as np #We need to import the numpy library to compute the mean of a list of complex
#The standard statistics library does not work with complex.
#import statistics
import matplotlib.pyplot as plt
import cmath as cmath #We will not use this library here, thus we do not need to import it.
#We shocased it to note that it has additional features for workign with complex beyond those of the standard math library and even the numpy
# -you can explore them. Another library with extra features for complex numbers is Scipy.

# %%
#Preliminary: some Useful python functions
# Use of a constructor to create a complex number
num = complex(2,4)
print(num)

# But don't need to, because python automatically recognises j as a complex number
num2 = 3+2j
print(num2)
print(type(num2))

# Python has some built-in accessors
print(num2.real)
print(num2.imag)
print(num2.conjugate())
print(abs((num2)))#Module
# Out:
# (2+4j)
# (3+2j)
# <class 'complex'>
# 3.0
# 2.0
# (3-2j)
# 1.4142135623730951

# %%
#Solutions from a) to f) in sequence
#Note that Python won't understand "j" b, we need to type it as "1j"

z=-(1j/2)*(1j+1j); print(z)
z=-(1/1j)*(1j**7); print(z)
z=((1+1j).conjugate())/(1j**2); print(z)
z=(2j/abs(2+2j))*(math.sqrt(2)/1j); print(z) 
z=(5*math.sqrt(5))*(    ((2+1j)/abs(2+1j))/(2-1j)  ); print(z) 
z_list=[2+1j,-1-1j,-1-2j,1,1j]; print(np.mean(z_list)) #statistics.mean() ony works for real numbers
# Out:
# (1-0j)
# (1+0j)
# (-1+1j)
# (1+0j)
# (3.0000000000000004+4j)
# (0.2-0.2j)

# %%
#g)
z_all=[] 
for i in range(1,100):
    z = pow(1j,i)
    print(f"j raised to the power of {i}:    {z}")
    z_all.append(z)
    plt.plot(z.real,z.imag,'o')
plt.grid() 
#Thus, the number simply rotates 90 degrees. 
#Note how j=j^5=j^9=...
# Out:
# j raised to the power of 1:    1j
# j raised to the power of 2:    (-1+0j)
# j raised to the power of 3:    (-0-1j)
# j raised to the power of 4:    (1+0j)
# j raised to the power of 5:    1j
# j raised to the power of 6:    (-1+0j)
# j raised to the power of 7:    (-0-1j)
# j raised to the power of 8:    (1+0j)
# j raised to the power of 9:    1j
# j raised to the power of 10:    (-1+0j)
# j raised to the power of 11:    (-0-1j)
# j raised to the power of 12:    (1+0j)
# j raised to the power of 13:    1j
# j raised to the power of 14:    (-1+0j)
# j raised to the power of 15:    (-0-1j)
# j raised to the power of 16:    (1+0j)
# j raised to the power of 17:    1j
# j raised to the power of 18:    (-1+0j)
# j raised to the power of 19:    (-0-1j)
# j raised to the power of 20:    (1+0j)
# j raised to the power of 21:    1j
# j raised to the power of 22:    (-1+0j)
# j raised to the power of 23:    (-0-1j)
# j raised to the power of 24:    (1+0j)
# j raised to the power of 25:    1j
# ...

# %%
z=-1j*(  ((4+4j).conjugate())/(2j*pow((1+1j),2)) ) 
print(z)
print()  
z_all=[] 
for i in range(1,100):
    u = pow(1j,i)
    z_new=z*u
    print(f"i={i}  new z={z_new}")
    plt.plot(z_new.real,z_new.imag,'o')
    z_all.append(z_new)
#Indicating the inital z. Every 4 iterations we end up here again.
#This product is simply rotating the original number 90 degrees (90 X 4=360)
plt.text((z.real-0.2),(z.imag-0.2*z.imag),'Initial z') 
plt.grid()
# Out:
# (1+1j)
#
# i=1  new z=(-1+1j)
# i=2  new z=(-1-1j)
# i=3  new z=(1-1j)
# i=4  new z=(1+1j)
# i=5  new z=(-1+1j)
# i=6  new z=(-1-1j)
# i=7  new z=(1-1j)
# i=8  new z=(1+1j)
# i=9  new z=(-1+1j)
# i=10  new z=(-1-1j)
# i=11  new z=(1-1j)
# i=12  new z=(1+1j)
# i=13  new z=(-1+1j)
# i=14  new z=(-1-1j)
# i=15  new z=(1-1j)
# i=16  new z=(1+1j)
# i=17  new z=(-1+1j)
# i=18  new z=(-1-1j)
# i=19  new z=(1-1j)
# i=20  new z=(1+1j)
# i=21  new z=(-1+1j)
# i=22  new z=(-1-1j)
# i=23  new z=(1-1j)
# i=24  new z=(1+1j)
# i=25  new z=(-1+1j)
# i=26  new z=(-1-1j)
# i=27  new z=(1-1j)
# i=28  new z=(1+1j)
# i=29  new z=(-1+1j)
# i=30  new z=(-1-1j)
# i=31  new z=(1-1j)
# i=32  new z=(1+1j)
# i=33  new z=(-1+1j)
# i=34  new z=(-1-1j)
# i=35  new z=(1-1j)
# i=36  new z=(1+1j)
# i=37  new z=(-1+1j)
# i=38  new z=(-1-1j)
# i=39  new z=(1-1j)
# i=40  new z=(1+1j)
# i=41  new z=(-1+1j)
# i=42  new z=(-1-1j)
# i=43  new z=(1-1j)
# i=44  new z=(1+1j)
# i=45  new z=(-1+1j)
# i=46  new z=(-1-1j)
# ...
