# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **plot one vecto**

# %%
v = np.array([1, 1])
plt.plot([0, v[0]], [0, v[1]], label=f'alpha')
plt.arrow(0,0, v[0], v[1])

# %%
w = np.array([1,1])
alphas2 = [3, 2, 1, 0, 5, 0]
for i, value in enumerate(alphas2):
    alpha = np.sqrt(value)
    v = w*alpha
    plt.plot([0, v[0]], [0, v[1]], label=f'alpha {i + 1}: {alpha:.2f}')
    plt.arrow(0, 0, v[0], v[1], head_width=0.05, head_length=0.05)
    print('vector', v)
    print('length for alpha', alpha, 'is', np.linalg.norm(v))

    plt.legend(fontsize=10, loc= 'upper left')
# Out:
# vector [1.73205081 1.73205081]
# length for alpha 1.7320508075688772 is 2.449489742783178
# vector [1.41421356 1.41421356]
# length for alpha 1.4142135623730951 is 2.0
# vector [1. 1.]
# length for alpha 1.0 is 1.4142135623730951
# vector [0. 0.]
# length for alpha 0.0 is 0.0
# vector [2.23606798 2.23606798]
# length for alpha 2.23606797749979 is 3.1622776601683795
# vector [0. 0.]
# length for alpha 0.0 is 0.0

# %% [markdown]
# finish at home

# %%
w = np.array([3, 4])
alphas2 = [3, 2, 1, 0, 5, 0]
for i, value in enumerate(alphas2):
    alpha = np.sqrt(value)
    v = w*alpha
    v = v/np.random.rand()
    plt.plot([0, v[0]], [0, v[1]], label=f'alpha {i + 1}: {alpha:.2f}')
    plt.arrow(0, 0, v[0], v[1], head_width=0.05, head_length=0.05)
    print('vector', v)
    print('length for alpha', alpha, 'is', np.linalg.norm(v))

    plt.legend(fontsize=10, loc= 'upper left')
# Out:
# vector [6.10829413 8.14439218]
# length for alpha 1.7320508075688772 is 10.180490223090766
# vector [370.32335746 493.76447661]
# length for alpha 1.4142135623730951 is 617.205595764635
# vector [20.71020799 27.61361065]
# length for alpha 1.0 is 34.517013317363165
# vector [0. 0.]
# length for alpha 0.0 is 0.0
# vector [38.84748146 51.79664195]
# length for alpha 2.23606797749979 is 64.74580243863059
# vector [0. 0.]
# length for alpha 0.0 is 0.0
