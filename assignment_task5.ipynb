# %%
import math
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from multiset import Multiset
a = 13

# %% [markdown]
# **5.1) Answer**$$(13)(q \oplus p) \oplus r \leftrightarrow (\neg q \rightarrow \neg r) where:\\ p = S \cap {a, 0} \equiv {a}\\ q = {-\infty} \subset\\ r= S \cup {0} \subset S $$

# %%
answer = '''The player needs to choose the right hand lift as a is false.
On the left hand of the equivilence we have inside the bracket with the proposition (p XOR q), as both are false the bracket is false. The proposition (p XOR q) XOR r is true, therefore the left hand side propositon is True.
The right hand side of the equivalence is false, the negation of q is true and the negation of r is false. Since it is a logical implication, the proposition is false. 
The left hand side is not equivalent to the right hand side, therefore the equivalent proposition is false.
As a is a constant and cannot change the answer of the left hand side we carry out equivalent propositon first and multiply a by the outcome.
The final answer a = 0 or boolean False.'''

print(answer)
# Out:
# The player needs to choose the right hand lift as a is false.
# On the left hand of the equivilence we have inside the bracket with the proposition (p XOR q), as both are false the bracket is false. The proposition (p XOR q) XOR r is true, therefore the left hand side propositon is True.
# The right hand side of the equivalence is false, the negation of q is true and the negation of r is false. Since it is a logical implication, the proposition is false.
# The left hand side is not equivalent to the right hand side, therefore the equivalent proposition is false.
# As a is a constant and cannot change the answer of the left hand side we carry out equivalent propositon first and multiply a by the outcome.
# The final answer a = 0 or boolean False.

# %% [markdown]
# **5.2) Element 1,  Permutations:** $$ P(n, r) = \frac{n!}{(n - r)!} $$

# %%
'''
The notation P(a, 1) represents the pemuatations of the set, a is equal to the number of elements and 1 the group size to choose from.
A permutation is the order of elements from a set. The elements can be repeated as long as the order of elements is unique.
    
The formula for nPr is n!/(n-r)!. 
n represents the number of elements, r the group size and ! is the factorial operator. The total elements a, is equal to 13. 

The group size is 1, meaning only one element can be chosen from total a, per pemutation. The order cannot be repeated.
Therefore there are 13 permutations.

'''
# We can check this answer the using formula.
perm = int((math.factorial(a))/math.factorial(a - 1))
print(perm)

# Set is currently defined as ...
s = {13}
# Out:
# 13

# %% [markdown]
# **5.2) Element 2,  Combinations:** $$ \binom{n}{r} = \frac{n!}{r!(n - r)!} $$

# %%
'''
The notation (a, 1) represents the combinations of the set, a is equal to number of elements and 1 the group size to choose from
Combinations are similar to permutations but an important distiction is the selection of an element is unique. Meaning once an element has been chosen it cannot be chosen again. 
(A, B, C) <=> (A, C, B), these combiantions are equivalant and neither unique.
 
 The formula for nCr is n!/(n-r)!r!. 
 n represents the number of elements, r the group size and is the operator factorial! The total elements a, is equal to 13.
 
 The group size is 1, meaning only one element can be chosen once from total a. Once the element has been chosen it cannot be selected again.
 Therefore there are 13 combinations.


'''

# We can check this answer using the math library combinations function using variable a from last cell.
comb = math.comb(a, 1)
print(comb)


# As s is a multiset and can contain repeated vaues, the set is currently defined as ...
set = [13, 13]
s = Multiset(set)
print('s =', s)
# Out:
# 13
# s = {13, 13}

# %% [markdown]
# **5.2) Element 3,  Limit:**
#
# $$
# \lim_{x \to 0} -\frac{a!}{x}
# $$

# %%
'''

f(x) = -13!/x
The limit of f(x) as x approches 0 in this scenario may depend on the direction of approach. 
If we approach from the negative direction, we get a postive Y value, as two minus multiplied make a postitive, as the X value approachs 0 the Y value increases and tends towards positive infinity.
If we approach from the positive direction, we get a negative Y value, as positve and minus multiplied make a negative, as the X value approaches 0 the Y value decreases and tends towards negative infinity.

As there are no restrictions on the directon as x approaches to 0, the answer is both positive and negative infinity which is not possible. Unless a direction is specified in the question, the answer is undefined.

Therefore the answer is undefined and a non-answer(NaN).

'''

# We can see this behaviour graphically. Y value tends towards postive and negative infintiy, depending on direction as X approaches 0. With a vertical asymptote at X = 0.


x = np.linspace(-10000, 10000, 100000)
y_num = math.factorial(a)
y_den = x
y = -(y_num/y_den)

mpl.rcParams['font.size']=14
plt.plot(x, y, 'r--')
plt.xlim(-10000, 10000)

plt.legend([r'$f(x) = \frac{13!}{x}$'])
plt.xlabel('x')
plt.ylabel('y (logscale)', rotation= 0)
plt.grid()
plt.axhline(c='black', linewidth=1)
plt.axvline(c='blue', linestyle='--', linewidth=1)
plt.yscale('symlog') 
plt.yticks([1e10, 1e8, 1e6, 1e4, 1e2, 0, -1e2, -1e4, - 1e6, - 1e8, -1e10 ])
plt.show()

set = [13, 13, np.nan]

# The set s is currently defined as...

s = Multiset(set)
print('s =', s)
# Out:
# s = {13, 13, nan}

# %% [markdown]
# **5.2) Element 4 is limit from task 3 and  equals 0, therefore: s = {13, 13, NaN, 0}**

# %% [markdown]
# **5.2) Boolean logic proposition**  $$(13)(q \oplus p) \oplus r \leftrightarrow (\neg q \rightarrow \neg r) where:\\ p = S \cap {a, 0} \equiv {a}\\ q = {-\infty} \subset\\ r= S \cup {0} \subset S $$

# %%
set = [13, 13, np.nan, 0]
s = Multiset(set)
# The set s = {13, 13, NaN, 0
print('s =', s)


# As there is no python function for implies, we need to code a function to carry out and implied logical operation.
def implies(a, b):

    if a and not b:
        return False
    else:
        return True

# Define p, q, r from logical problem as boolean value.
set = {a, 0}
p = s.intersection(set) == {a}
q = {-math.inf}.issubset(s)

r = (s + {0}).issubset(s)

# Output boolean values of p, q, r.
print('p is equal to', p, ', q is equal to', q,'and r is equal to', r,)


'''
So far we have defined the set, we have also defined p as False, since the set of intersection is {a, 0} and is not equivilant to {a}.
We have defined q as False as negative infinty is not a subset of s. 
We have also defined r as True as the set of union is {a, 0} and therefore is a subset of s, as the set is a subset of itself.
'''

#True in python is equivilant to integer 1 and the identity element we can show this with output...
print('It is', True == 1, 'that boolean True == 1 in pyhton.')


'''
Starting with the left hand side (lhs) and beginning iside the bracket. We have inside the bracket the proposition p XOR q, as both are false the propostion is false. Then the result of the bracket(False) XOR r, as
r is true the proposition is true. Since a is integer we will resolve all propositional statements before using a.
'''

# Output lhs to show True answer.
lhs = (p^q)^(r)
print('Value for left hand side is ', lhs,'.')

'''
Continuing with the right hand side (rhs), the implication of not q and not r. Since the negation of q is True, the second statement needs to be True for the implication to be true.
The negation of r is False therefore the implication is False so the rhs is False.

'''
# Output rhs to show boolean value is false.
rhs = print('The answer to the implied proposition is ', (implies(not q, not r)))

'''
Final statement: the lhs is True, the right hand side is False. Since they are not equivilant the proposition is false.
a multiplied by False = 0, which is equal to Boolean False. Therefore 
'''
#True in python is equivilant to integer 1 and the identity element we can show this with output...
print('It is', True == 1, 'that boolean True == 1 in pyhton.')

# Output final logical value, using result of entire propostion and equivilant proposition.
a = a*(lhs == rhs)

print('a value is equal to', a, 'which is equal to boolean', (lhs == rhs) )

truth_of_the_matter = (p^q)^r == implies(not q, not r)
print(truth_of_the_matter)
# Out:
# s = {13, 13, nan, 0}
# p is equal to False , q is equal to False and r is equal to False
# It is True that boolean True == 1 in pyhton.
# Value for left hand side is  False .
# The answer to the implied proposition is  True
# It is True that boolean True == 1 in pyhton.
# a value is equal to 0 which is equal to boolean False
# False
